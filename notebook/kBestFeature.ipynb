# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import feather
import scipy as sp 
from time import time
from sklearn.manifold import spectral_embedding
from sklearn.cluster import spectral_clustering
from sklearn.cluster.spectral import SpectralClustering
from sklearn.metrics import pairwise_distances
from sklearn.metrics.pairwise import *
import pickle
from sklearn.utils.graph import graph_laplacian
from sklearn.utils.arpack import eigsh
from sklearn.manifold.spectral_embedding_ import _set_diag
from scipy.linalg import eigvals, eigvalsh
import seaborn
from matplotlib.backends.backend_pdf import PdfPages
from sklearn.grid_search import GridSearchCV
from sklearn import tree
from sklearn.feature_selection import SelectKBest
from sklearn.cross_validation import train_test_split
from sklearn.model_selection import train_test_split
from scipy.stats import randint as sp_randint

# %matplotlib inline
# Out:
# /home/sam/.virtualenvs/ist558Project/local/lib/python2.7/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /home/sam/.virtualenvs/ist558Project/local/lib/python2.7/site-packages/sklearn/grid_search.py:43: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)

# %%
def test_clf(grid_search, features, labels, parameters, iterations=100):
    from sklearn.metrics import classification_report
    precision, recall = [], []
    for iteration in range(iterations):
        features_train, features_test, labels_train, labels_test = train_test_split(features, labels, random_state=iteration)
        grid_search.fit(features_train, labels_train)
        predictions = grid_search.predict(features_test)
    print classification_report(labels_test, predictions)
    best_params = grid_search.best_estimator_.get_params()
    for param_name in sorted(parameters.keys()):
        print '%s=%r, ' % (param_name, best_params[param_name])

# %%
label = pd.read_csv('../data/recomm_spectral_clustering_discretize.label.csv', index_col='biz_id')
label_checkin = pd.read_csv('../data/morethan5_discretize.label.csv', index_col='biz_id')
precom = pd.read_csv('../data/tfidf_all_biz_1percom.csv', index_col='biz_id')

# %%
more10_list = []
for indx in precom.index:
    if sum(precom.loc[indx,:] > 0) >= 10:
        if indx not in more10_list:
            more10_list.append(indx)

# %%
precom = precom.loc[more10_list, :]
precom2 = precom.copy()

# %%
for biz in label.index:
    precom.loc[biz, 'label' ] = label.label.loc[biz]
for biz in label_checkin.index:
    precom2.loc[biz, 'label' ] = label_checkin.label.loc[biz]

# %%
meat = ['meati', 'meat', 'steak', 'beef', 'pork', 'lamb', 'hamburg', 'kabob']
alcohol = ['beer', 'wine', 'cocktail', 'alcohol', 'martini', 'mimosa',
          'sangria', 'vodka', 'champagn', 'liquor', 'bourbon', 'tequilla', 'whiskey']

trans_alcohol = precom.loc[:, alcohol].mean(axis=1)
trans_meat = precom.loc[:, meat].mean(axis=1)

trans_alcohol2 = precom2.loc[:, alcohol].mean(axis=1)
trans_meat2 = precom2.loc[:, meat].mean(axis=1)

# %%
precom_na = precom.dropna()
features = precom_na.drop('label', axis=1).values
labels = precom_na.label.values

precom2_na = precom2.dropna()
features2 = precom2_na.drop('label', axis=1).values
labels2 = precom2_na.label.values

# %%
precom_reduced = precom.drop(alcohol + meat, axis=1 )
precom_reduced['alcohol'] = trans_alcohol.values
precom_reduced['meat'] = trans_meat.values
precom_reduced_na = precom_reduced.dropna()
features3 = precom_reduced_na.drop('label', axis=1)
labels3 = precom_reduced_na.label.values

precom2_reduced = precom2.drop(alcohol + meat, axis=1 )
precom2_reduced['alcohol'] = trans_alcohol2.values
precom2_reduced['meat'] = trans_meat2.values
precom2_reduced_na = precom2_reduced.dropna()
features4 = precom2_reduced_na.drop('label', axis=1)
labels4 = precom2_reduced_na.label.values

# %%
clf = tree.DecisionTreeClassifier()
t0= time()
parameters = {'criterion': ['gini', 'entropy'],
               'min_samples_split': [2, 10, 20],
               'max_depth': [None, 2, 5, 10],
               'min_samples_leaf': [1, 5, 10],
               'max_leaf_nodes': [None, 5, 10, 20]}
grid_search = GridSearchCV(clf, parameters)
for i in range(2,60):
    k_best = SelectKBest(k=i)
    k_features = k_best.fit_transform(features3, labels3)
    print "K best features with k = {0}".format(i)
    test_clf(grid_search, k_features, labels3, parameters, iterations=20)

print '\nDecision Tree  (Best k features):'

print '\nDecision Tree total time:{0}s'.format(round(time()-t0, 3))
# Out:
# K best features with k = 2
#              precision    recall  f1-score   support
#
#         0.0       0.26      0.86      0.40       297
#         1.0       0.09      0.01      0.01       154
#         2.0       0.37      0.23      0.28       172
#         3.0       0.00      0.00      0.00       113
#         4.0       0.00      0.00      0.00       153
#         5.0       0.23      0.12      0.15       302
#         6.0       0.00      0.00      0.00        56
#
# avg / total       0.18      0.26      0.17      1247
#
# criterion='gini',
# max_depth=None,
# max_leaf_nodes=10,
# min_samples_leaf=1,
# min_samples_split=10,
# K best features with k = 3
#              precision    recall  f1-score   support
#
#         0.0       0.26      0.77      0.39       297
#         1.0       0.20      0.04      0.07       154
#         2.0       0.33      0.15      0.21       172
#         3.0       0.21      0.04      0.06       113
#         4.0       0.11      0.03      0.05       153
#         5.0       0.21      0.13      0.16       302
#         6.0       0.00      0.00      0.00        56
#
# avg / total       0.21      0.25      0.18      1247
#
# criterion='gini',
# max_depth=10,
# max_leaf_nodes=None,
# min_samples_leaf=1,
# min_samples_split=20,
# K best features with k = 4
#              precision    recall  f1-score   support
#
#         0.0       0.25      0.86      0.39       297
#         1.0       0.00      0.00      0.00       154
#         2.0       0.39      0.20      0.27       172
#         3.0       0.00      0.00      0.00       113
#         4.0       0.00      0.00      0.00       153
#         5.0       0.22      0.10      0.13       302
#         6.0       0.00      0.00      0.00        56
#
# avg / total       0.17      0.26      0.16      1247
#
# criterion='gini',
# max_depth=2,
# max_leaf_nodes=10,
# min_samples_leaf=5,
# min_samples_split=2,
# K best features with k = 5
#              precision    recall  f1-score   support
#
#         0.0       0.25      0.75      0.38       297
#         1.0       0.00      0.00      0.00       154
#         2.0       0.39      0.20      0.26       172
#         3.0       0.00      0.00      0.00       113
#         4.0       0.17      0.03      0.05       153
#         5.0       0.23      0.20      0.21       302
#         6.0       0.00      0.00      0.00        56
#
# avg / total       0.19      0.26      0.18      1247
#
# criterion='gini',
# max_depth=None,
# max_leaf_nodes=10,
# min_samples_leaf=10,
# min_samples_split=2,
# K best features with k = 6
#              precision    recall  f1-score   support
#
#         0.0       0.25      0.87      0.39       297
#         1.0       0.00      0.00      0.00       154
#         2.0       0.39      0.20      0.27       172
#         3.0       0.00      0.00      0.00       113
#         4.0       0.00      0.00      0.00       153
#         5.0       0.22      0.10      0.13       302
#         6.0       0.00      0.00      0.00        56
#
# avg / total       0.17      0.26      0.16      1247
#
# criterion='gini',
# max_depth=2,
# max_leaf_nodes=5,
# min_samples_leaf=1,
# min_samples_split=2,
# K best features with k = 7
#              precision    recall  f1-score   support
#
#         0.0       0.25      0.87      0.39       297
#         1.0       0.00      0.00      0.00       154
#         2.0       0.39      0.20      0.27       172
#         3.0       0.00      0.00      0.00       113
#         4.0       0.00      0.00      0.00       153
#         5.0       0.22      0.10      0.13       302
#         6.0       0.00      0.00      0.00        56
#
# avg / total       0.17      0.26      0.16      1247
#
# criterion='gini',
# max_depth=2,
# max_leaf_nodes=5,
# min_samples_leaf=1,
# min_samples_split=2,
# K best features with k = 8
#              precision    recall  f1-score   support
#
#         0.0       0.25      0.84      0.39       297
#         1.0       0.00      0.00      0.00       154
#         2.0       0.43      0.20      0.28       172
#         3.0       0.00      0.00      0.00       113
#         4.0       0.14      0.03      0.05       153
#         5.0       0.22      0.10      0.13       302
#         6.0       0.00      0.00      0.00        56
#
# avg / total       0.19      0.26      0.17      1247
#
# criterion='gini',
# max_depth=None,
# max_leaf_nodes=10,
# min_samples_leaf=10,
# min_samples_split=2,
# K best features with k = 9
#              precision    recall  f1-score   support
#
#         0.0       0.25      0.86      0.39       297
#         1.0       0.00      0.00      0.00       154
#         2.0       0.40      0.20      0.26       172
#         3.0       0.00      0.00      0.00       113
#         4.0       0.25      0.01      0.02       153
#         5.0       0.21      0.10      0.13       302
#         6.0       0.00      0.00      0.00        56
#
# avg / total       0.20      0.26      0.16      1247
#
# criterion='gini',
# max_depth=None,
# max_leaf_nodes=10,
# min_samples_leaf=1,
# min_samples_split=20,
# K best features with k = 10
#              precision    recall  f1-score   support
#
#         0.0       0.25      0.86      0.39       297
#         1.0       0.00      0.00      0.00       154
#         2.0       0.39      0.23      0.29       172
#         3.0       0.00      0.00      0.00       113
#         4.0       0.27      0.02      0.04       153
#         5.0       0.24      0.09      0.13       302
#         6.0       0.00      0.00      0.00        56
#
# avg / total       0.21      0.26      0.17      1247
#
# criterion='entropy',
# max_depth=None,
# max_leaf_nodes=10,
# min_samples_leaf=10,
# min_samples_split=2,
# K best features with k = 11
#              precision    recall  f1-score   support
#
#         0.0       0.25      0.86      0.39       297
#         1.0       0.00      0.00      0.00       154
#         2.0       0.44      0.20      0.28       172
#         3.0       0.00      0.00      0.00       113
#         4.0       0.13      0.01      0.02       153
#         5.0       0.22      0.10      0.13       302
#         6.0       0.00      0.00      0.00        56
#
# avg / total       0.19      0.26      0.17      1247
#
# criterion='gini',
# max_depth=5,
# max_leaf_nodes=20,
# min_samples_leaf=5,
# min_samples_split=20,
# K best features with k = 12
#              precision    recall  f1-score   support
#
#         0.0       0.25      0.83      0.38       297
#         1.0       0.00      0.00      0.00       154
#         2.0       0.44      0.20      0.28       172
#         3.0       0.00      0.00      0.00       113
#         4.0       0.13      0.01      0.02       153
#         5.0       0.23      0.12      0.16       302
#         6.0       0.00      0.00      0.00        56
#
# avg / total       0.19      0.26      0.17      1247
#
# criterion='gini',
# max_depth=5,
# max_leaf_nodes=20,
# min_samples_leaf=5,
# min_samples_split=20,
# K best features with k = 13
#              precision    recall  f1-score   support
#
#         0.0       0.25      0.87      0.39       297
#         1.0       0.00      0.00      0.00       154
#         2.0       0.40      0.16      0.22       172
#         3.0       0.00      0.00      0.00       113
#         4.0       0.00      0.00      0.00       153
#         5.0       0.21      0.11      0.15       302
#         6.0       0.00      0.00      0.00        56
#
# avg / total       0.17      0.26      0.16      1247
#
# criterion='entropy',
# max_depth=None,
# max_leaf_nodes=5,
# min_samples_leaf=1,
# min_samples_split=2,
# K best features with k = 14
#              precision    recall  f1-score   support
#
#         0.0       0.25      0.87      0.39       297
#         1.0       0.00      0.00      0.00       154
#         2.0       0.40      0.16      0.22       172
#         3.0       0.00      0.00      0.00       113
#         4.0       0.00      0.00      0.00       153
#         5.0       0.21      0.11      0.15       302
#         6.0       0.00      0.00      0.00        56
#
# avg / total       0.17      0.26      0.16      1247
#
# criterion='entropy',
# max_depth=None,
# max_leaf_nodes=5,
# min_samples_leaf=1,
# min_samples_split=2,
# K best features with k = 15
#              precision    recall  f1-score   support
#
#         0.0       0.25      0.87      0.39       297
#         1.0       0.00      0.00      0.00       154
#         2.0       0.40      0.16      0.22       172
#         3.0       0.00      0.00      0.00       113
#         4.0       0.00      0.00      0.00       153
#         5.0       0.21      0.11      0.15       302
#         6.0       0.00      0.00      0.00        56
#
# avg / total       0.17      0.26      0.16      1247
#
# criterion='entropy',
# max_depth=None,
# max_leaf_nodes=5,
# min_samples_leaf=1,
# min_samples_split=2,
# K best features with k = 16
#              precision    recall  f1-score   support
#
#         0.0       0.25      0.87      0.39       297
#         1.0       0.00      0.00      0.00       154
#         2.0       0.71      0.13      0.22       172
#         3.0       0.22      0.07      0.11       113
#         4.0       0.00      0.00      0.00       153
#         5.0       0.21      0.11      0.15       302
#         6.0       0.00      0.00      0.00        56
#
# avg / total       0.23      0.26      0.17      1247
#
# criterion='entropy',
# max_depth=None,
# max_leaf_nodes=5,
# min_samples_leaf=1,
# min_samples_split=2,
# K best features with k = 17
#              precision    recall  f1-score   support
#
#         0.0       0.25      0.87      0.39       297
#         1.0       0.00      0.00      0.00       154
#         2.0       0.71      0.13      0.22       172
#         3.0       0.22      0.07      0.11       113
#         4.0       0.00      0.00      0.00       153
#         5.0       0.21      0.11      0.15       302
#         6.0       0.00      0.00      0.00        56
#
# avg / total       0.23      0.26      0.17      1247
#
# criterion='entropy',
# max_depth=None,
# max_leaf_nodes=5,
# min_samples_leaf=1,
# min_samples_split=2,
# K best features with k = 18
#              precision    recall  f1-score   support
#
#         0.0       0.25      0.85      0.39       297
#         1.0       0.00      0.00      0.00       154
#         2.0       0.52      0.22      0.31       172
#         3.0       0.20      0.07      0.10       113
#         4.0       0.08      0.01      0.01       153
#         5.0       0.23      0.09      0.13       302
#         6.0       0.00      0.00      0.00        56
#
# avg / total       0.21      0.26      0.18      1247
#
# criterion='entropy',
# max_depth=None,
# max_leaf_nodes=10,
# min_samples_leaf=10,
# min_samples_split=2,
# K best features with k = 19
#              precision    recall  f1-score   support
#
#         0.0       0.25      0.85      0.39       297
#         1.0       0.20      0.03      0.06       154
#         2.0       0.62      0.17      0.26       172
#         3.0       0.06      0.01      0.02       113
#         4.0       0.14      0.01      0.02       153
#         5.0       0.21      0.10      0.14       302
#         6.0       0.00      0.00      0.00        56
#
# avg / total       0.25      0.26      0.17      1247
#
# criterion='entropy',
# max_depth=5,
# max_leaf_nodes=20,
# min_samples_leaf=1,
# min_samples_split=20,
# K best features with k = 20
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-66b1c4b61006> in <module>()
#      11     k_features = k_best.fit_transform(features3, labels3)
#      12     print "K best features with k = {0}".format(i)
# ---> 13     test_clf(grid_search, k_features, labels3, parameters, iterations=20)
#      14
#      15 print '\nDecision Tree  (Best k features):'
#
# <ipython-input-2-127472dec46e> in test_clf(grid_search, features, labels, parameters, iterations)
#       4     for iteration in range(iterations):
#       5         features_train, features_test, labels_train, labels_test = train_test_split(features, labels, random_state=iteration)
# ----> 6         grid_search.fit(features_train, labels_train)
#       7         predictions = grid_search.predict(features_test)
#       8     print classification_report(labels_test, predictions)
#
# /home/sam/.virtualenvs/ist558Project/local/lib/python2.7/site-packages/sklearn/grid_search.pyc in fit(self, X, y)
#     827
#     828         """
# --> 829         return self._fit(X, y, ParameterGrid(self.param_grid))
#     830
#     831
#
# /home/sam/.virtualenvs/ist558Project/local/lib/python2.7/site-packages/sklearn/grid_search.pyc in _fit(self, X, y, parameter_iterable)
#     571                                     self.fit_params, return_parameters=True,
#     572                                     error_score=self.error_score)
# --> 573                 for parameters in parameter_iterable
#     574                 for train, test in cv)
#     575
#
# /home/sam/.virtualenvs/ist558Project/local/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in __call__(self, iterable)
#     756             # was dispatched. In particular this covers the edge
#     757             # case of Parallel used with an exhausted iterator.
# --> 758             while self.dispatch_one_batch(iterator):
#     759                 self._iterating = True
#     760             else:
#
# /home/sam/.virtualenvs/ist558Project/local/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in dispatch_one_batch(self, iterator)
#     606                 return False
#     607             else:
# --> 608                 self._dispatch(tasks)
#     609                 return True
#     610
#
# /home/sam/.virtualenvs/ist558Project/local/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in _dispatch(self, batch)
#     569         dispatch_timestamp = time.time()
#     570         cb = BatchCompletionCallBack(dispatch_timestamp, len(batch), self)
# --> 571         job = self._backend.apply_async(batch, callback=cb)
#     572         self._jobs.append(job)
#     573
#
# /home/sam/.virtualenvs/ist558Project/local/lib/python2.7/site-packages/sklearn/externals/joblib/_parallel_backends.pyc in apply_async(self, func, callback)
#     107     def apply_async(self, func, callback=None):
#     108         """Schedule a func to be run"""
# --> 109         result = ImmediateResult(func)
#     110         if callback:
#     111             callback(result)
#
# /home/sam/.virtualenvs/ist558Project/local/lib/python2.7/site-packages/sklearn/externals/joblib/_parallel_backends.pyc in __init__(self, batch)
#     324         # Don't delay the application, to avoid keeping the input
#     325         # arguments in memory
# --> 326         self.results = batch()
#     327
#     328     def get(self):
#
# /home/sam/.virtualenvs/ist558Project/local/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in __call__(self)
#     129
#     130     def __call__(self):
# --> 131         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#     132
#     133     def __len__(self):
#
# /home/sam/.virtualenvs/ist558Project/local/lib/python2.7/site-packages/sklearn/cross_validation.pyc in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, error_score)
#    1652
#    1653     if parameters is not None:
# -> 1654         estimator.set_params(**parameters)
#    1655
#    1656     start_time = time.time()
#
# /home/sam/.virtualenvs/ist558Project/local/lib/python2.7/site-packages/sklearn/base.pyc in set_params(self, **params)
#     270             # Simple optimisation to gain speed (inspect is slow)
#     271             return self
# --> 272         valid_params = self.get_params(deep=True)
#     273         for key, value in six.iteritems(params):
#     274             split = key.split('__', 1)
#
# /home/sam/.virtualenvs/ist558Project/local/lib/python2.7/site-packages/sklearn/base.pyc in get_params(self, deep)
#     233         """
#     234         out = dict()
# --> 235         for key in self._get_param_names():
#     236             # We need deprecation warnings to always be on in order to
#     237             # catch deprecated param values.
#
# /home/sam/.virtualenvs/ist558Project/local/lib/python2.7/site-packages/sklearn/base.pyc in _get_param_names(cls)
#     203         # introspect the constructor arguments to find the model parameters
#     204         # to represent
# --> 205         init_signature = signature(init)
#     206         # Consider the constructor parameters excluding 'self'
#     207         parameters = [p for p in init_signature.parameters.values()
#
# /home/sam/.virtualenvs/ist558Project/local/lib/python2.7/site-packages/sklearn/externals/funcsigs.pyc in signature(obj)
#      60
#      61     if isinstance(obj, types.MethodType):
# ---> 62         sig = signature(obj.__func__)
#      63         if obj.__self__ is None:
#      64             # Unbound method: the first parameter becomes positional-only
#
# /home/sam/.virtualenvs/ist558Project/local/lib/python2.7/site-packages/sklearn/externals/funcsigs.pyc in signature(obj)
#      92
#      93     if isinstance(obj, types.FunctionType):
# ---> 94         return Signature.from_function(obj)
#      95
#      96     if isinstance(obj, functools.partial):
#
# /home/sam/.virtualenvs/ist558Project/local/lib/python2.7/site-packages/sklearn/externals/funcsigs.pyc in from_function(cls, func)
#     581         return cls(parameters,
#     582                    return_annotation=annotations.get('return', _empty),
# --> 583                    __validate_parameters__=False)
#     584
#     585     @property
#
# /home/sam/.virtualenvs/ist558Project/local/lib/python2.7/site-packages/sklearn/externals/funcsigs.pyc in __init__(self, parameters, return_annotation, __validate_parameters__)
#     505             else:
#     506                 params = OrderedDict(((param.name, param)
# --> 507                                                 for param in parameters))
#     508
#     509         self._parameters = params
#
# /usr/lib/python2.7/collections.pyc in __init__(*args, **kwds)
#      67             root[:] = [root, root, None]
#      68             self.__map = {}
# ---> 69         self.__update(*args, **kwds)
#      70
#      71     def __setitem__(self, key, value, dict_setitem=dict.__setitem__):
#
# /home/sam/.virtualenvs/ist558Project/lib/python2.7/abc.pyc in __subclasscheck__(cls, subclass)
#     149         """Override for issubclass(subclass, cls)."""
#     150         # Check cache
# --> 151         if subclass in cls._abc_cache:
#     152             return True
#     153         # Check negative cache; may have to invalidate
#
# /home/sam/.virtualenvs/ist558Project/lib/python2.7/_weakrefset.pyc in __contains__(self, item)
#      68         return len(self.data) - len(self._pending_removals)
#      69
# ---> 70     def __contains__(self, item):
#      71         try:
#      72             wr = ref(item)
#
# KeyboardInterrupt:

# %%
from sklearn.ensemble import ExtraTreesClassifier

clf = ExtraTreesClassifier(n_jobs=4)
t0= time()
parameters = {'n_estimators': [10],
              'criterion': ['gini', 'entropy'],
              'max_depth': [None, 2, 5, 10], 
              'min_samples_split': [2, 10, 20],
              'min_samples_leaf': [1, 5, 10], 
              'max_leaf_nodes': [None, 5, 10, 20]}
grid_search = GridSearchCV(clf, parameters)
for i in [2,3,4,5]:
    k_best = SelectKBest(k=i)
    k_features = k_best.fit_transform(features, labels)
    print "K best features with k = {0}".format(i)
    test_clf(grid_search, k_features, labels, parameters, )

print '\nDecision Tree  (Best k features):'

print '\nDecision Tree total time:{0}s'.format(round(time()-t0, 3))

# %%
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier()
t0= time()
parameters = {'n_estimators':[10],
              'criterion': ['gini'],
              'max_depth': [10], 
              'min_samples_split': [10],
              'min_samples_leaf': [5], 
              'max_leaf_nodes': [None]}
grid_search = GridSearchCV(clf, parameters)
for i in [38]:
    k_best = SelectKBest(k=i)
    k_features = k_best.fit_transform(features4, labels4)
    print "K best features with k = {0}".format(i)
    test_clf(grid_search, k_features, labels4, parameters, iterations=1)

print '\nDecision Tree  (Best k features):'

print '\nDecision Tree total time:{0}s'.format(round(time()-t0, 3))
# Out:
# K best features with k = 38
#              precision    recall  f1-score   support
#
#         0.0       0.20      0.06      0.09       193
#         1.0       0.36      0.90      0.51       385
#         2.0       0.52      0.24      0.33       267
#         3.0       0.00      0.00      0.00        25
#         4.0       0.75      0.17      0.28       103
#         5.0       1.00      0.02      0.05        81
#         6.0       0.33      0.01      0.02       122
#
# avg / total       0.44      0.38      0.29      1176
#
# criterion='gini',
# max_depth=10,
# max_leaf_nodes=None,
# min_samples_leaf=5,
# min_samples_split=10,
# n_estimators=10,
#
# Decision Tree  (Best k features):
#
# Decision Tree total time:0.283s

# %%
# k_features = vpd.read_csv('../report/k-best-user-visit.csv')
g = []
for c in features4.columns:
    for i in range(k_features.shape[1]):
        if np.array_equal(features4.loc[:, c].values, k_features[:, i]):
            g.append(c)
len(g)
# Out:
# 38

# %%
a = pd.DataFrame(k_features)
a.to_csv('../report/k-best-rating.csv')

# %%
from sklearn.ensemble import AdaBoostClassifier
from time import time
clf = AdaBoostClassifier()
t0= time()
parameters = {'n_estimators': [10, 20, 40],
               'algorithm': ['SAMME', 'SAMME.R'],
               'learning_rate': [.5, 1, 1.5]}
grid_search = GridSearchCV(clf, parameters)
for i in [2,3,4,5]:
    k_best = SelectKBest(k=i)
    k_features = k_best.fit_transform(features, labels)
    print "K best features with k = {0}".format(i)
    test_clf(grid_search, k_features, labels, parameters)

print '\nAdaBoost (Best k features):'

print '\nAdaBoost total time:{0}s'.format(round(time()-t0, 3))
# Out:
# /home/sam/.virtualenvs/ist558Project/local/lib/python2.7/site-packages/sklearn/feature_selection/univariate_selection.py:113: UserWarning: Features [ 30 114 215 238] are constant.
#   UserWarning)
# K best features with k = 2
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-842fb9a2998e> in <module>()
#      11     k_features = k_best.fit_transform(features, labels)
#      12     print "K best features with k = {0}".format(i)
# ---> 13     test_clf2(grid_search, k_features, labels, parameters)
#      14
#      15 print '\nAdaBoost (Best k features):'
#
# <ipython-input-42-4a46b7a40868> in test_clf2(random_search, features, labels, parameters, iterations)
#       4     random_search.fit(features, labels)
#       5     print("RandomizedSearchCV took %.2f seconds for %d candidates"
# ----> 6           " parameter settings." % ((time() - start), n_iter_search))
#       7     report(random_search.cv_results_)
#
# NameError: global name 'start' is not defined

# %%
from sklearn.naive_bayes import GaussianNB
clf = GaussianNB()
t0= time()
parameters = {}
grid_search = GridSearchCV(clf, parameters)
for i in range(2, 60):
    k_best = SelectKBest(k=i)
    k_features = k_best.fit_transform(features3, labels3)
    print "K best features with k = {0}".format(i)
    test_clf(grid_search, k_features, labels3, parameters)

print '\nGaussianNB  (Best k features):'

print '\nGaussianNB total time:{0}s'.format(round(time()-t0, 3))
# Out:
# K best features with k = 2
#              precision    recall  f1-score   support
#
#         0.0       0.24      0.94      0.38       282
#         1.0       0.00      0.00      0.00       138
#         2.0       0.33      0.13      0.18       175
#         3.0       0.00      0.00      0.00       100
#         4.0       0.00      0.00      0.00       155
#         5.0       0.28      0.05      0.09       331
#         6.0       0.00      0.00      0.00        66
#
# avg / total       0.17      0.24      0.13      1247
#
# K best features with k = 3
#              precision    recall  f1-score   support
#
#         0.0       0.24      0.92      0.38       282
#         1.0       0.00      0.00      0.00       138
#         2.0       0.34      0.10      0.16       175
#         3.0       0.15      0.02      0.04       100
#         4.0       0.00      0.00      0.00       155
#         5.0       0.20      0.04      0.06       331
#         6.0       0.00      0.00      0.00        66
#
# avg / total       0.17      0.23      0.13      1247
#
# K best features with k = 4
#              precision    recall  f1-score   support
#
#         0.0       0.24      0.90      0.38       282
#         1.0       0.10      0.02      0.04       138
#         2.0       0.33      0.10      0.15       175
#         3.0       0.13      0.03      0.05       100
#         4.0       0.10      0.02      0.03       155
#         5.0       0.26      0.04      0.06       331
#         6.0       0.00      0.00      0.00        66
#
# avg / total       0.20      0.23      0.14      1247
#
# K best features with k = 5
#              precision    recall  f1-score   support
#
#         0.0       0.24      0.89      0.38       282
#         1.0       0.11      0.03      0.05       138
#         2.0       0.32      0.10      0.16       175
#         3.0       0.12      0.03      0.05       100
#         4.0       0.12      0.02      0.03       155
#         5.0       0.32      0.04      0.07       331
#         6.0       0.00      0.00      0.00        66
#
# avg / total       0.22      0.24      0.14      1247
#
# K best features with k = 6
#              precision    recall  f1-score   support
#
#         0.0       0.24      0.89      0.38       282
#         1.0       0.12      0.02      0.04       138
#         2.0       0.31      0.10      0.15       175
#         3.0       0.13      0.03      0.05       100
#         4.0       0.07      0.01      0.02       155
#         5.0       0.31      0.03      0.06       331
#         6.0       0.08      0.05      0.06        66
#
# avg / total       0.22      0.23      0.14      1247
#
# K best features with k = 7
#              precision    recall  f1-score   support
#
#         0.0       0.24      0.89      0.38       282
#         1.0       0.09      0.02      0.03       138
#         2.0       0.33      0.11      0.16       175
#         3.0       0.10      0.02      0.03       100
#         4.0       0.13      0.03      0.04       155
#         5.0       0.23      0.03      0.05       331
#         6.0       0.06      0.03      0.04        66
#
# avg / total       0.20      0.23      0.14      1247
#
# K best features with k = 8
#              precision    recall  f1-score   support
#
#         0.0       0.18      0.04      0.06       282
#         1.0       0.12      0.03      0.05       138
#         2.0       0.35      0.11      0.17       175
#         3.0       0.11      0.03      0.05       100
#         4.0       0.15      0.02      0.03       155
#         5.0       0.23      0.03      0.05       331
#         6.0       0.06      0.86      0.11        66
#
# avg / total       0.19      0.09      0.07      1247
#
# K best features with k = 9
#              precision    recall  f1-score   support
#
#         0.0       0.19      0.04      0.06       282
#         1.0       0.13      0.04      0.06       138
#         2.0       0.34      0.11      0.16       175
#         3.0       0.10      0.03      0.05       100
#         4.0       0.19      0.03      0.05       155
#         5.0       0.23      0.03      0.06       331
#         6.0       0.05      0.82      0.10        66
#
# avg / total       0.20      0.09      0.07      1247
#
# K best features with k = 10
#              precision    recall  f1-score   support
#
#         0.0       0.20      0.05      0.08       282
#         1.0       0.09      0.02      0.04       138
#         2.0       0.41      0.11      0.18       175
#         3.0       0.06      0.02      0.03       100
#         4.0       0.17      0.03      0.04       155
#         5.0       0.22      0.04      0.06       331
#         6.0       0.05      0.82      0.10        66
#
# avg / total       0.20      0.09      0.08      1247
#
# K best features with k = 11
#              precision    recall  f1-score   support
#
#         0.0       0.20      0.05      0.08       282
#         1.0       0.10      0.02      0.04       138
#         2.0       0.41      0.11      0.18       175
#         3.0       0.08      0.03      0.04       100
#         4.0       0.11      0.02      0.03       155
#         5.0       0.25      0.04      0.07       331
#         6.0       0.05      0.82      0.10        66
#
# avg / total       0.20      0.09      0.08      1247
#
# K best features with k = 12
#              precision    recall  f1-score   support
#
#         0.0       0.18      0.04      0.06       282
#         1.0       0.07      0.01      0.02       138
#         2.0       0.42      0.13      0.19       175
#         3.0       0.00      0.00      0.00       100
#         4.0       0.14      0.03      0.04       155
#         5.0       0.22      0.03      0.05       331
#         6.0       0.05      0.83      0.10        66
#
# avg / total       0.19      0.08      0.07      1247
#
# K best features with k = 13
#              precision    recall  f1-score   support
#
#         0.0       0.20      0.04      0.07       282
#         1.0       0.14      0.03      0.05       138
#         2.0       0.43      0.13      0.19       175
#         3.0       0.02      0.01      0.01       100
#         4.0       0.14      0.03      0.04       155
#         5.0       0.21      0.03      0.05       331
#         6.0       0.06      0.83      0.10        66
#
# avg / total       0.20      0.09      0.07      1247
#
# K best features with k = 14
#              precision    recall  f1-score   support
#
#         0.0       0.20      0.04      0.07       282
#         1.0       0.03      0.01      0.01       138
#         2.0       0.44      0.13      0.20       175
#         3.0       0.07      0.03      0.04       100
#         4.0       0.14      0.03      0.04       155
#         5.0       0.18      0.02      0.04       331
#         6.0       0.06      0.85      0.11        66
#
# avg / total       0.18      0.08      0.07      1247
#
# K best features with k = 15
#              precision    recall  f1-score   support
#
#         0.0       0.25      0.05      0.09       282
#         1.0       0.03      0.01      0.01       138
#         2.0       0.39      0.13      0.19       175
#         3.0       0.09      0.04      0.06       100
#         4.0       0.19      0.03      0.05       155
#         5.0       0.21      0.02      0.04       331
#         6.0       0.06      0.85      0.11        66
#
# avg / total       0.20      0.09      0.07      1247
#
# K best features with k = 16
#              precision    recall  f1-score   support
#
#         0.0       0.23      0.05      0.08       282
#         1.0       0.06      0.01      0.02       138
#         2.0       0.37      0.13      0.19       175
#         3.0       0.10      0.04      0.06       100
#         4.0       0.16      0.02      0.03       155
#         5.0       0.24      0.03      0.05       331
#         6.0       0.06      0.83      0.10        66
#
# avg / total       0.20      0.09      0.07      1247
#
# K best features with k = 17
#              precision    recall  f1-score   support
#
#         0.0       0.21      0.04      0.07       282
#         1.0       0.08      0.02      0.03       138
#         2.0       0.38      0.13      0.19       175
#         3.0       0.07      0.03      0.04       100
#         4.0       0.16      0.02      0.03       155
#         5.0       0.27      0.03      0.06       331
#         6.0       0.06      0.83      0.10        66
#
# avg / total       0.21      0.09      0.08      1247
#
# K best features with k = 18
#              precision    recall  f1-score   support
#
#         0.0       0.18      0.04      0.06       282
#         1.0       0.03      0.01      0.01       138
#         2.0       0.38      0.13      0.19       175
#         3.0       0.07      0.03      0.04       100
#         4.0       0.18      0.02      0.03       155
#         5.0       0.23      0.03      0.06       331
#         6.0       0.05      0.82      0.10        66
#
# avg / total       0.19      0.08      0.07      1247
#
# K best features with k = 19
#              precision    recall  f1-score   support
#
#         0.0       0.20      0.04      0.07       282
#         1.0       0.03      0.01      0.01       138
#         2.0       0.38      0.13      0.19       175
#         3.0       0.09      0.04      0.06       100
#         4.0       0.18      0.02      0.03       155
#         5.0       0.26      0.03      0.06       331
#         6.0       0.05      0.80      0.10        66
#
# avg / total       0.20      0.08      0.07      1247
#
# K best features with k = 20
#              precision    recall  f1-score   support
#
#         0.0       0.16      0.02      0.04       282
#         1.0       0.06      0.01      0.02       138
#         2.0       0.39      0.13      0.19       175
#         3.0       0.09      0.04      0.05       100
#         4.0       0.17      0.02      0.03       155
#         5.0       0.22      0.03      0.05       331
#         6.0       0.05      0.79      0.10        66
#
# avg / total       0.19      0.08      0.07      1247
#
# K best features with k = 21
#              precision    recall  f1-score   support
#
#         0.0       0.15      0.02      0.04       282
#         1.0       0.08      0.02      0.03       138
#         2.0       0.39      0.13      0.19       175
#         3.0       0.09      0.04      0.05       100
#         4.0       0.16      0.02      0.03       155
#         5.0       0.22      0.03      0.05       331
#         6.0       0.05      0.79      0.10        66
#
# avg / total       0.19      0.08      0.07      1247
#
# K best features with k = 22
#              precision    recall  f1-score   support
#
#         0.0       0.26      0.04      0.07       282
#         1.0       0.06      0.01      0.02       138
#         2.0       0.38      0.13      0.19       175
#         3.0       0.09      0.04      0.06       100
#         4.0       0.17      0.02      0.03       155
#         5.0       0.21      0.02      0.04       331
#         6.0       0.05      0.80      0.10        66
#
# avg / total       0.21      0.08      0.07      1247
#
# K best features with k = 23
#              precision    recall  f1-score   support
#
#         0.0       0.27      0.04      0.07       282
#         1.0       0.06      0.01      0.02       138
#         2.0       0.38      0.13      0.19       175
#         3.0       0.09      0.04      0.05       100
#         4.0       0.19      0.03      0.05       155
#         5.0       0.22      0.03      0.05       331
#         6.0       0.05      0.79      0.10        66
#
# avg / total       0.21      0.09      0.07      1247
#
# K best features with k = 24
#              precision    recall  f1-score   support
#
#         0.0       0.29      0.05      0.08       282
#         1.0       0.07      0.01      0.02       138
#         2.0       0.37      0.13      0.19       175
#         3.0       0.09      0.04      0.05       100
#         4.0       0.21      0.03      0.05       155
#         5.0       0.26      0.03      0.05       331
#         6.0       0.05      0.77      0.10        66
#
# avg / total       0.23      0.09      0.08      1247
#
# K best features with k = 25
#              precision    recall  f1-score   support
#
#         0.0       0.26      0.05      0.08       282
#         1.0       0.07      0.01      0.02       138
#         2.0       0.35      0.13      0.19       175
#         3.0       0.08      0.04      0.05       100
#         4.0       0.19      0.02      0.04       155
#         5.0       0.23      0.03      0.05       331
#         6.0       0.05      0.77      0.10        66
#
# avg / total       0.21      0.09      0.08      1247
#
# K best features with k = 26
#              precision    recall  f1-score   support
#
#         0.0       0.20      0.04      0.06       282
#         1.0       0.06      0.01      0.02       138
#         2.0       0.32      0.13      0.18       175
#         3.0       0.10      0.04      0.06       100
#         4.0       0.18      0.02      0.03       155
#         5.0       0.16      0.02      0.03       331
#         6.0       0.05      0.79      0.10        66
#
# avg / total       0.17      0.08      0.06      1247
#
# K best features with k = 27
#              precision    recall  f1-score   support
#
#         0.0       0.21      0.04      0.07       282
#         1.0       0.03      0.01      0.01       138
#         2.0       0.33      0.13      0.18       175
#         3.0       0.08      0.04      0.05       100
#         4.0       0.18      0.02      0.03       155
#         5.0       0.14      0.01      0.02       331
#         6.0       0.05      0.79      0.10        66
#
# avg / total       0.17      0.08      0.06      1247
#
# K best features with k = 28
#              precision    recall  f1-score   support
#
#         0.0       0.20      0.04      0.06       282
#         1.0       0.07      0.01      0.02       138
#         2.0       0.33      0.13      0.18       175
#         3.0       0.08      0.04      0.05       100
#         4.0       0.17      0.02      0.03       155
#         5.0       0.17      0.02      0.03       331
#         6.0       0.05      0.79      0.10        66
#
# avg / total       0.17      0.08      0.06      1247
#
# K best features with k = 29
#              precision    recall  f1-score   support
#
#         0.0       0.25      0.05      0.08       282
#         1.0       0.07      0.01      0.02       138
#         2.0       0.33      0.13      0.19       175
#         3.0       0.08      0.04      0.05       100
#         4.0       0.12      0.01      0.02       155
#         5.0       0.19      0.02      0.03       331
#         6.0       0.05      0.79      0.10        66
#
# avg / total       0.18      0.08      0.07      1247
#
# K best features with k = 30
#              precision    recall  f1-score   support
#
#         0.0       0.24      0.05      0.08       282
#         1.0       0.09      0.02      0.04       138
#         2.0       0.33      0.13      0.19       175
#         3.0       0.08      0.04      0.05       100
#         4.0       0.13      0.01      0.02       155
#         5.0       0.21      0.02      0.03       331
#         6.0       0.05      0.79      0.10        66
#
# avg / total       0.19      0.08      0.07      1247
#
# K best features with k = 31
#              precision    recall  f1-score   support
#
#         0.0       0.20      0.04      0.07       282
#         1.0       0.11      0.02      0.04       138
#         2.0       0.33      0.14      0.19       175
#         3.0       0.08      0.04      0.05       100
#         4.0       0.13      0.01      0.02       155
#         5.0       0.27      0.02      0.04       331
#         6.0       0.05      0.79      0.10        66
#
# avg / total       0.20      0.08      0.07      1247
#
# K best features with k = 32
#              precision    recall  f1-score   support
#
#         0.0       0.20      0.04      0.07       282
#         1.0       0.09      0.01      0.02       138
#         2.0       0.34      0.15      0.21       175
#         3.0       0.08      0.04      0.05       100
#         4.0       0.14      0.01      0.02       155
#         5.0       0.26      0.02      0.04       331
#         6.0       0.05      0.79      0.10        66
#
# avg / total       0.20      0.08      0.07      1247
#
# K best features with k = 33
#              precision    recall  f1-score   support
#
#         0.0       0.22      0.04      0.07       282
#         1.0       0.08      0.01      0.02       138
#         2.0       0.35      0.15      0.21       175
#         3.0       0.08      0.04      0.05       100
#         4.0       0.12      0.01      0.02       155
#         5.0       0.30      0.03      0.05       331
#         6.0       0.05      0.79      0.10        66
#
# avg / total       0.21      0.09      0.07      1247
#
# K best features with k = 34
#              precision    recall  f1-score   support
#
#         0.0       0.21      0.04      0.07       282
#         1.0       0.09      0.01      0.02       138
#         2.0       0.35      0.15      0.21       175
#         3.0       0.09      0.04      0.05       100
#         4.0       0.12      0.01      0.02       155
#         5.0       0.29      0.02      0.04       331
#         6.0       0.05      0.79      0.10        66
#
# avg / total       0.21      0.09      0.07      1247
#
# K best features with k = 35
#              precision    recall  f1-score   support
#
#         0.0       0.21      0.04      0.07       282
#         1.0       0.13      0.02      0.04       138
#         2.0       0.35      0.15      0.21       175
#         3.0       0.09      0.04      0.05       100
#         4.0       0.12      0.01      0.02       155
#         5.0       0.30      0.03      0.05       331
#         6.0       0.05      0.79      0.10        66
#
# avg / total       0.22      0.09      0.08      1247
#
# K best features with k = 36
#              precision    recall  f1-score   support
#
#         0.0       0.22      0.05      0.08       282
#         1.0       0.11      0.02      0.04       138
#         2.0       0.36      0.15      0.21       175
#         3.0       0.11      0.05      0.07       100
#         4.0       0.11      0.01      0.02       155
#         5.0       0.31      0.03      0.06       331
#         6.0       0.05      0.77      0.10        66
#
# avg / total       0.22      0.09      0.08      1247
#
# K best features with k = 37
#              precision    recall  f1-score   support
#
#         0.0       0.21      0.05      0.08       282
#         1.0       0.11      0.02      0.04       138
#         2.0       0.36      0.15      0.22       175
#         3.0       0.12      0.05      0.07       100
#         4.0       0.12      0.01      0.02       155
#         5.0       0.32      0.03      0.06       331
#         6.0       0.05      0.77      0.10        66
#
# avg / total       0.22      0.09      0.08      1247
#
# K best features with k = 38
#              precision    recall  f1-score   support
#
#         0.0       0.24      0.05      0.08       282
#         1.0       0.07      0.01      0.02       138
#         2.0       0.36      0.15      0.22       175
#         3.0       0.12      0.05      0.07       100
#         4.0       0.11      0.01      0.02       155
#         5.0       0.34      0.03      0.06       331
#         6.0       0.05      0.79      0.10        66
#
# avg / total       0.23      0.09      0.08      1247
#
# K best features with k = 39
#              precision    recall  f1-score   support
#
#         0.0       0.25      0.05      0.08       282
#         1.0       0.07      0.01      0.02       138
#         2.0       0.36      0.15      0.22       175
#         3.0       0.12      0.05      0.07       100
#         4.0       0.11      0.01      0.02       155
#         5.0       0.34      0.03      0.06       331
#         6.0       0.05      0.79      0.10        66
#
# avg / total       0.23      0.09      0.08      1247
#
# K best features with k = 40
#              precision    recall  f1-score   support
#
#         0.0       0.28      0.05      0.08       282
#         1.0       0.06      0.01      0.02       138
#         2.0       0.37      0.15      0.21       175
#         3.0       0.11      0.05      0.07       100
#         4.0       0.11      0.01      0.02       155
#         5.0       0.32      0.03      0.06       331
#         6.0       0.05      0.80      0.10        66
#
# avg / total       0.23      0.09      0.08      1247
#
# K best features with k = 41
#              precision    recall  f1-score   support
#
#         0.0       0.23      0.04      0.06       282
#         1.0       0.07      0.01      0.02       138
#         2.0       0.37      0.15      0.21       175
#         3.0       0.12      0.05      0.07       100
#         4.0       0.10      0.01      0.02       155
#         5.0       0.27      0.03      0.05       331
#         6.0       0.05      0.80      0.10        66
#
# avg / total       0.21      0.09      0.07      1247
#
# K best features with k = 42
#              precision    recall  f1-score   support
#
#         0.0       0.23      0.04      0.06       282
#         1.0       0.10      0.02      0.04       138
#         2.0       0.37      0.15      0.21       175
#         3.0       0.11      0.05      0.07       100
#         4.0       0.10      0.01      0.02       155
#         5.0       0.26      0.03      0.05       331
#         6.0       0.05      0.80      0.10        66
#
# avg / total       0.21      0.09      0.07      1247
#
# K best features with k = 43
#              precision    recall  f1-score   support
#
#         0.0       0.24      0.04      0.07       282
#         1.0       0.11      0.03      0.05       138
#         2.0       0.37      0.15      0.21       175
#         3.0       0.11      0.05      0.07       100
#         4.0       0.11      0.01      0.02       155
#         5.0       0.26      0.03      0.05       331
#         6.0       0.05      0.80      0.10        66
#
# avg / total       0.21      0.09      0.08      1247
#
# K best features with k = 44
#              precision    recall  f1-score   support
#
#         0.0       0.24      0.04      0.07       282
#         1.0       0.09      0.02      0.03       138
#         2.0       0.37      0.15      0.21       175
#         3.0       0.11      0.05      0.07       100
#         4.0       0.11      0.01      0.02       155
#         5.0       0.25      0.03      0.05       331
#         6.0       0.05      0.80      0.10        66
#
# avg / total       0.21      0.09      0.08      1247
#
# K best features with k = 45
#              precision    recall  f1-score   support
#
#         0.0       0.24      0.04      0.07       282
#         1.0       0.09      0.02      0.03       138
#         2.0       0.37      0.15      0.21       175
#         3.0       0.11      0.05      0.07       100
#         4.0       0.10      0.01      0.02       155
#         5.0       0.27      0.03      0.05       331
#         6.0       0.05      0.80      0.10        66
#
# avg / total       0.21      0.09      0.08      1247
#
# K best features with k = 46
#              precision    recall  f1-score   support
#
#         0.0       0.24      0.05      0.08       282
#         1.0       0.09      0.02      0.04       138
#         2.0       0.35      0.14      0.20       175
#         3.0       0.11      0.05      0.07       100
#         4.0       0.10      0.01      0.02       155
#         5.0       0.30      0.03      0.05       331
#         6.0       0.05      0.80      0.10        66
#
# avg / total       0.22      0.09      0.08      1247
#
# K best features with k = 47
#              precision    recall  f1-score   support
#
#         0.0       0.21      0.04      0.07       282
#         1.0       0.11      0.03      0.05       138
#         2.0       0.35      0.14      0.20       175
#         3.0       0.12      0.05      0.07       100
#         4.0       0.14      0.02      0.03       155
#         5.0       0.31      0.03      0.06       331
#         6.0       0.05      0.80      0.10        66
#
# avg / total       0.22      0.09      0.08      1247
#
# K best features with k = 48
#              precision    recall  f1-score   support
#
#         0.0       0.22      0.04      0.07       282
#         1.0       0.09      0.02      0.03       138
#         2.0       0.35      0.14      0.20       175
#         3.0       0.11      0.05      0.07       100
#         4.0       0.09      0.01      0.02       155
#         5.0       0.31      0.03      0.06       331
#         6.0       0.05      0.80      0.10        66
#
# avg / total       0.21      0.09      0.07      1247
#
# K best features with k = 49
#              precision    recall  f1-score   support
#
#         0.0       0.25      0.05      0.08       282
#         1.0       0.11      0.03      0.05       138
#         2.0       0.35      0.14      0.20       175
#         3.0       0.11      0.05      0.07       100
#         4.0       0.14      0.02      0.03       155
#         5.0       0.31      0.03      0.06       331
#         6.0       0.05      0.80      0.10        66
#
# avg / total       0.23      0.09      0.08      1247
#
# K best features with k = 50
#              precision    recall  f1-score   support
#
#         0.0       0.25      0.05      0.08       282
#         1.0       0.12      0.03      0.05       138
#         2.0       0.34      0.14      0.20       175
#         3.0       0.11      0.05      0.07       100
#         4.0       0.14      0.02      0.03       155
#         5.0       0.29      0.03      0.05       331
#         6.0       0.05      0.79      0.10        66
#
# avg / total       0.22      0.09      0.08      1247
#
# K best features with k = 51
#              precision    recall  f1-score   support
#
#         0.0       0.24      0.04      0.07       282
#         1.0       0.12      0.03      0.05       138
#         2.0       0.34      0.14      0.20       175
#         3.0       0.12      0.05      0.07       100
#         4.0       0.20      0.03      0.05       155
#         5.0       0.27      0.03      0.05       331
#         6.0       0.05      0.79      0.10        66
#
# avg / total       0.22      0.09      0.08      1247
#
# K best features with k = 52
#              precision    recall  f1-score   support
#
#         0.0       0.23      0.04      0.07       282
#         1.0       0.09      0.02      0.04       138
#         2.0       0.35      0.15      0.21       175
#         3.0       0.12      0.05      0.07       100
#         4.0       0.20      0.03      0.05       155
#         5.0       0.27      0.03      0.05       331
#         6.0       0.05      0.79      0.10        66
#
# avg / total       0.22      0.09      0.08      1247
#
# K best features with k = 53
#              precision    recall  f1-score   support
#
#         0.0       0.25      0.04      0.07       282
#         1.0       0.09      0.02      0.04       138
#         2.0       0.35      0.14      0.20       175
#         3.0       0.11      0.05      0.07       100
#         4.0       0.18      0.03      0.05       155
#         5.0       0.26      0.03      0.05       331
#         6.0       0.05      0.79      0.10        66
#
# avg / total       0.22      0.09      0.08      1247
#
# K best features with k = 54
#              precision    recall  f1-score   support
#
#         0.0       0.26      0.05      0.08       282
#         1.0       0.09      0.02      0.03       138
#         2.0       0.36      0.14      0.20       175
#         3.0       0.11      0.05      0.07       100
#         4.0       0.18      0.03      0.05       155
#         5.0       0.24      0.03      0.05       331
#         6.0       0.05      0.80      0.10        66
#
# avg / total       0.22      0.09      0.08      1247
#
# K best features with k = 55
#              precision    recall  f1-score   support
#
#         0.0       0.26      0.05      0.08       282
#         1.0       0.10      0.02      0.04       138
#         2.0       0.35      0.14      0.20       175
#         3.0       0.11      0.05      0.07       100
#         4.0       0.18      0.03      0.05       155
#         5.0       0.26      0.03      0.05       331
#         6.0       0.05      0.82      0.10        66
#
# avg / total       0.22      0.09      0.08      1247
#
# K best features with k = 56
#              precision    recall  f1-score   support
#
#         0.0       0.26      0.05      0.08       282
#         1.0       0.10      0.02      0.04       138
#         2.0       0.36      0.14      0.20       175
#         3.0       0.14      0.06      0.08       100
#         4.0       0.18      0.03      0.05       155
#         5.0       0.27      0.04      0.06       331
#         6.0       0.05      0.82      0.10        66
#
# avg / total       0.23      0.09      0.08      1247
#
# K best features with k = 57
#              precision    recall  f1-score   support
#
#         0.0       0.27      0.05      0.08       282
#         1.0       0.10      0.02      0.04       138
#         2.0       0.36      0.14      0.20       175
#         3.0       0.14      0.06      0.08       100
#         4.0       0.15      0.03      0.04       155
#         5.0       0.27      0.04      0.06       331
#         6.0       0.05      0.82      0.10        66
#
# avg / total       0.23      0.09      0.09      1247
#
# K best features with k = 58
#              precision    recall  f1-score   support
#
#         0.0       0.27      0.05      0.08       282
#         1.0       0.10      0.02      0.04       138
#         2.0       0.36      0.14      0.20       175
#         3.0       0.14      0.06      0.08       100
#         4.0       0.15      0.03      0.04       155
#         5.0       0.26      0.03      0.06       331
#         6.0       0.05      0.80      0.10        66
#
# avg / total       0.22      0.09      0.08      1247
#
# K best features with k = 59
#              precision    recall  f1-score   support
#
#         0.0       0.27      0.05      0.08       282
#         1.0       0.07      0.01      0.02       138
#         2.0       0.36      0.14      0.20       175
#         3.0       0.14      0.06      0.08       100
#         4.0       0.16      0.03      0.04       155
#         5.0       0.26      0.04      0.06       331
#         6.0       0.05      0.80      0.10        66
#
# avg / total       0.22      0.09      0.08      1247
#
#
# GaussianNB  (Best k features):
#
# GaussianNB total time:157.048s
