# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import feather
import scipy as sp 
import time
from sklearn.manifold import spectral_embedding
from sklearn.cluster import spectral_clustering
from sklearn.cluster.spectral import SpectralClustering
from sklearn.metrics import pairwise_distances
from sklearn.metrics.pairwise import *
import pickle
from sklearn.utils.graph import graph_laplacian
from sklearn.utils.arpack import eigsh
from sklearn.manifold.spectral_embedding_ import _set_diag
from scipy.linalg import eigvals, eigvalsh
import seaborn
from matplotlib.backends.backend_pdf import PdfPages


# %matplotlib inline

# %%
M = feather.read_dataframe('../data/sim_matrix_5more_II.feather')

# %%
# biz_id = pd.read_csv('../data/5more_biz_id_II.csv')

# %%
sM = sp.sparse.csr_matrix(M.values, dtype=int)

# %%
similarity = cosine_similarity(sM)

# %%
similarity = cosine_similarity(sM)
normed_laplacian, dd = graph_laplacian(similarity, normed=True, return_diag=True)
laplacian = _set_diag(normed_laplacian, 1, 0)


n_components = similarity.shape[0] - 1


eigenvalues, eigenvectors = eigsh(-laplacian, k=20, which="LM", sigma=1.0, maxiter=5000)
# eigenvalues = eigvalsh(-laplacian)
eigenvalues = -eigenvalues[::-1]  # Reverse and sign inversion.

max_gap = 0
gap_pre_index = 0
gaps = []
for i in range(1, eigenvalues.size):
    gap = eigenvalues[i] - eigenvalues[i - 1]
    gaps.append(gap)
    if gap > max_gap:
        max_gap = gap
        gap_pre_index = i - 1

k = gap_pre_index + 1
plt.plot(range(1, eigenvalues.size)[1:20], gaps[1:20], '-o')

# %%
plt.figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')
plt.plot(range(1, eigenvalues.size)[1:20], gaps[1:20], '-o')
plt.ylabel('eigenGap')
plt.savefig('eigengap.pdf', format='pdf')

# %%
plt.figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')
plt.plot(range(0,20), eigenvalues[:20], 'o')
plt.ylabel('eigenValue')
plt.savefig('eigenvalues.pdf', format='pdf')

# %%
cl = SpectralClustering(n_clusters=7,
                        assign_labels='discretize',
                        affinity='precomputed', 
#                         eigen_solver='amg',
                        random_state=10,
                        n_jobs=-1)

label = cl.fit_predict(similarity)
a = plt.hist(label)

# %%
indx = pd.read_csv('../data/5more_biz_id_II.csv')
labels = pd.DataFrame({'biz_id' :  indx.biz_id, 'label' : label})
labels.to_csv('../data/morethan5_discretize.label.csv')
